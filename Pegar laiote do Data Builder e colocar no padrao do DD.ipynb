# %%
import pandas as pd

# %%
caminho = 'C:\\Projetos\\Python\\Data Builder\\'
arquivo = 'Processo_Id8847_EmpresasBrasil_20210806015605'

df = pd.read_excel(caminho + arquivo + '.xlsx')

# %%
df['Complemento'] = ''
df['Bairro'] = ''
df['Nome País'] = 'Brasil'
df['Porte'] = ''
df['Capital Social'] = ''
df['Capital Social de'] = ''
df['Capital Social até'] = ''
df['Faturamento de'] = ''
df['Faturamento até'] = ''
df['Quantidade de funcionários'] = ''
df['Quantidade de funcionários de'] = ''
df['Quantidade de funcionários até'] = ''
df['Gastos com Governo Federal'] = ''
df['Score total'] = ''
df['Score escalonado'] = ''
df['Tipo Enquadramento Porte'] = ''
df['Atividade econômica secundária'] = ''
df['Código optante Simples'] = ''
df['Data opção Simples'] = ''
df['Data exclusão Simples'] = ''
df['Código da qualificação do responsável'] = ''
df['Data da remessa'] = ''
df['Motivo da situação'] = ''
df['Data situação'] = ''
df['Tipo situação especial'] = ''
df['Data da situação especial'] = ''
df['Código da natureza jurídica'] = ''
df['Tipo de classificação jurídica'] = ''
df['Qualificação do responsável'] = ''
df['Cidade exterior'] = ''
df['Número CNPJ'] = ''
df['Tipo de qualificação'] = ''
df['Código país'] = ''
df['Opção MEI'] = ''
df['Atualizado em'] = ''
df['Website1'] = ''
df['Website2'] = ''
df['Website3'] = ''
df['Website4'] = ''
df['Website5'] = ''
df['Data entrada do sócio 1'] = ''
df['E-mail sócio 1'] = ''
df['Qualificação sócio 1'] = ''
df['Tipo qualificação sócio 1'] = ''
df['Data entrada do sócio 2'] = ''
df['E-mail sócio 2'] = ''
df['Qualificação sócio 2'] = ''
df['Tipo qualificação sócio 2'] = ''
df['Data entrada do sócio 3'] = ''
df['E-mail sócio 3'] = ''
df['Qualificação sócio 3'] = ''
df['Tipo qualificação sócio 3'] = ''
df['Data entrada do sócio 4'] = ''
df['E-mail sócio 4'] = ''
df['Qualificação sócio 4'] = ''
df['Tipo qualificação sócio 4'] = ''
df['Data entrada do sócio 5'] = ''
df['E-mail sócio '] = ''
df['Qualificação sócio 5'] = ''
df['Tipo qualificação sócio 5'] = ''
df['Assertividade Telefone 1'] = ''
df['Ranking Assertividade Telefone 1'] = ''
df['Telefone Verificado 1'] = ''
df['Telefone 2'] = ''
df['Assertividade Telefone 2'] = ''
df['Ranking Assertividade Telefone 2'] = ''
df['Telefone Verificado 2'] = ''
df['Telefone 3'] = ''
df['Assertividade Telefone 3'] = ''
df['Ranking Assertividade Telefone 3'] = ''
df['Telefone Verificado 3'] = ''
df['Telefone 4'] = ''
df['Assertividade Telefone 4'] = ''
df['Ranking Assertividade Telefone 4'] = ''
df['Telefone Verificado 4'] = ''
df['Telefone 5'] = ''
df['Assertividade Telefone 5'] = ''
df['Ranking Assertividade Telefone 5'] = ''
df['Telefone Verificado 5'] = ''
df['Numero'] = ''
df['Logradouro'] = ''

# %%
df['Logradouro'] = df['ENDERECO'].str.split(',', expand=True).get(0)
df['Numero'] = df['ENDERECO'].str.split(',', expand=True).get(1)
df['Numero'] = df['Numero'].str.strip()

# %%
df['Telefone 1'] = df['TELEFONES_LISTA'].str.split(';', expand=True).get(1)
df['Telefone 2'] = df['TELEFONES_LISTA'].str.split(';', expand=True).get(2)
df['Telefone 3'] = df['TELEFONES_LISTA'].str.split(';', expand=True).get(3)
df['Telefone 4'] = df['TELEFONES_LISTA'].str.split(';', expand=True).get(4)
df['Telefone 5'] = df['TELEFONES_LISTA'].str.split(';', expand=True).get(5)

# %%
df['Telefone 1'] = df['Telefone 1'].str.replace("55", "").str.replace('(', '').str.replace(')', '').str.replace('-', '').str.replace(' ', '').str.replace('+', '')
df['Telefone 2'] = df['Telefone 2'].str.replace("55", "").str.replace('(', '').str.replace(')', '').str.replace('-', '').str.replace(' ', '').str.replace('+', '')
df['Telefone 3'] = df['Telefone 3'].str.replace("55", "").str.replace('(', '').str.replace(')', '').str.replace('-', '').str.replace(' ', '').str.replace('+', '')
df['Telefone 4'] = df['Telefone 4'].str.replace("55", "").str.replace('(', '').str.replace(')', '').str.replace('-', '').str.replace(' ', '').str.replace('+', '')
df['Telefone 5'] = df['Telefone 5'].str.replace("55", "").str.replace('(', '').str.replace(')', '').str.replace('-', '').str.replace(' ', '').str.replace('+', '')
# Out:
# C:\Users\JOSE~1.PRO\AppData\Local\Temp/ipykernel_12536/1977045765.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Telefone 1'] = df['Telefone 1'].str.replace("55", "").str.replace('(', '').str.replace(')', '').str.replace('-', '').str.replace(' ', '').str.replace('+', '')
# C:\Users\JOSE~1.PRO\AppData\Local\Temp/ipykernel_12536/1977045765.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Telefone 2'] = df['Telefone 2'].str.replace("55", "").str.replace('(', '').str.replace(')', '').str.replace('-', '').str.replace(' ', '').str.replace('+', '')
# ...

# %%
df.rename(columns={'RAZAO_SOCIAL': 'Nome fantasia'}, inplace= True)
df.rename(columns={'EMPRESA': 'Razão social'}, inplace= True)
df.rename(columns={'CIDADE': 'Cidade'}, inplace= True)
df.rename(columns={'ESTADO': 'UF'}, inplace= True)
df.rename(columns={'CEP': 'CEP'}, inplace= True)
df.rename(columns={'DATA_DE_ABERTURA': 'Data da abertura'}, inplace= True)
df.rename(columns={'TIPO_UNIDADE': 'Tipo de unidade'}, inplace= True)
df.rename(columns={'SITUACAO_CADASTRAL': ' Tipo situação'}, inplace= True)
df.rename(columns={'ATIVIDADE_DESCRICAO1': 'Nome atividade econômica primária'}, inplace= True)
df.rename(columns={'ATIVIDADE_COD1': 'Código atividade econômica primária'}, inplace= True)
df.rename(columns={'NATUREZA_JURIDICA': 'Nome natureza jurídica geral'}, inplace= True)
df.rename(columns={'E-MAIL': 'E-mail na Receita Federal'}, inplace= True)
df.rename(columns={'CNPJ': 'Código CNPJ'}, inplace= True)
df.rename(columns={'SOCIO_NOME_1': 'Nome do sócio 1'}, inplace= True)
df.rename(columns={'SOCIO_NOME_2': 'Nome do sócio 2'}, inplace= True)
df.rename(columns={'SOCIO_NOME_3': 'Nome do sócio 3'}, inplace= True)
df.rename(columns={'SOCIO_NOME_4': 'Nome do sócio 4'}, inplace= True)
df.rename(columns={'SOCIO_NOME_5': 'Nome do sócio 5'}, inplace= True)

# %%
df['CEP'] = df['CEP'].str[:2] + '.' + df['CEP'].str[2:5] + '-' + df['CEP'].str[6:]

# %%
#df = df.filter(items=['Código CNPJ','Razão social','Nome fantasia','Logradouro', 'Numero','Complemento', 'Bairro', 'Cidade', 'UF', 'CEP', 'Porte', 'Capital Social até', 'Faturamento até','Quantidade de funcionários até', 'Data da abertura','Tipo de unidade', ' Tipo situação', 'Tipo Enquadramento Porte', 'Código atividade econômica primária', 'Nome atividade econômica primária', 'Código da natureza jurídica', 'Nome natureza jurídica geral', 'E-mail na Receita Federal','Tipo de classificação jurídica', 'Website1', 'Website2', 'Website3', 'Website4', 'Website5', 'Nome do sócio 1', 'Qualificação sócio 1','Tipo qualificação sócio 1', 'Nome do sócio 2','Qualificação sócio 2', 'Tipo qualificação sócio 2','Nome do sócio 3', 'Qualificação sócio 3', 'Tipo qualificação sócio 3','Nome do sócio 4', 'Qualificação sócio 4', 'Tipo qualificação sócio 4', 'Nome do sócio 5', 'Qualificação sócio 5', 'Tipo qualificação sócio 5', 'Telefone 1', 'Telefone 2', 'Telefone 3', 'Telefone 4', 'Telefone 5'])
#df = df.filter(items=[
#    'Nome fantasia',
#	'Razão social',
#	'Logradouro',
#	'Numero',
#	'Complemento',
#	'Bairro',
#	'Cidade',
#	'UF',
#	'CEP',
#	'Nome País',
#	'Porte',
#	'Capital Social',
#	'Capital Social de',
#	'Capital Social até',
#	'Faturamento de',
#	'Faturamento até',
#	'Quantidade de funcionários',
#	'Quantidade de funcionários de',
#	'Quantidade de funcionários até',
#	'Gastos com Governo Federal',
#	'Score total',
#	'Score escalonado',
#	'Data da abertura',
#	'Tipo de unidade',
#	' Tipo situação',
#	'Tipo Enquadramento Porte',
#	'Nome atividade econômica primária',
#	'Código atividade econômica primária',
#	'Atividade econômica secundária',
#	'Nome natureza jurídica geral',
#	'Código optante Simples',
#	'Data opção Simples',
#	'Data exclusão Simples',
#	'E-mail na Receita Federal',
#	'Código da qualificação do responsável',
#	'Data da remessa',
#	'Motivo da situação',
#	'Data situação',
#	'Tipo situação especial',
#	'Data da situação especial',
#	'Código da natureza jurídica',
#	'Tipo de classificação jurídica',
#	'Código CNPJ',
#	'Qualificação do responsável',
#	'Cidade exterior',
#	'Número CNPJ',
#	'Tipo de qualificação',
#	'Código país',
#	'Opção MEI',
#	'Atualizado em',
#	'Website1',
#	'Website2',
#	'Website3',
#	'Website4',
#	'Website5',
#	'Nome do sócio 1',
#	'Data entrada do sócio 1',
#	'E-mail sócio 1',
#	'Qualificação sócio 1',
#	'Tipo qualificação sócio 1',
#	'Nome do sócio 2',
#	'Data entrada do sócio 2',
#	'E-mail sócio 2',
#	'Qualificação sócio 2',
#	'Tipo qualificação sócio 2',
#	'Nome do sócio 3',
#	'Data entrada do sócio 3',
#	'E-mail sócio 3',
#	'Qualificação sócio 3',
#	'Tipo qualificação sócio 3',
#	'Nome do sócio 4',
#	'Data entrada do sócio 4',
#	'E-mail sócio 4',
#	'Qualificação sócio 4',
#	'Tipo qualificação sócio 4',
#	'Nome do sócio 5',
#	'Data entrada do sócio 5',
#	'E-mail sócio ',
#	'Qualificação sócio 5',
#	'Tipo qualificação sócio 5',
#	'Telefone 1',
#	'Assertividade Telefone 1',
#	'Ranking Assertividade Telefone 1',
#	'Telefone Verificado 1',
#	'Telefone 2',
#	'Assertividade Telefone 2',
#	'Ranking Assertividade Telefone 2',
#	'Telefone Verificado 2',
#	'Telefone 3',
#	'Assertividade Telefone 3',
#	'Ranking Assertividade Telefone 3',
#	'Telefone Verificado 3',
#	'Telefone 4',
#	'Assertividade Telefone 4',
#	'Ranking Assertividade Telefone 4',
#	'Telefone Verificado 4',
#	'Telefone 5',
#	'Assertividade Telefone 5',
#	'Ranking Assertividade Telefone 5',
#	'Telefone Verificado 5'
#])
df = df.filter(items=['Código CNPJ','Razão social','Nome fantasia','Logradouro', 'Numero','Complemento', 'Bairro', 'Cidade', 'UF', 'CEP', 'Porte', 'Capital Social', 'Capital Social de', 'Capital Social até', 'Faturamento de', 'Faturamento até', 'Quantidade de funcionários','Quantidade de funcionários de','Quantidade de funcionários até', 'Data da abertura','Tipo de unidade', ' Tipo situação', 'Nome atividade econômica primária', 'Nome natureza jurídica geral', 'E-mail na Receita Federal', 'Telefone 1', 'Telefone 2', 'Telefone 3', 'Telefone 4', 'Telefone 5', 'Website1', 'Website2', 'Website3', 'Website4', 'Website5', 'Nome do sócio 1', 'Qualificação sócio 1','Tipo qualificação sócio 1', 'Nome do sócio 2','Qualificação sócio 2', 'Tipo qualificação sócio 2','Nome do sócio 3', 'Qualificação sócio 3', 'Tipo qualificação sócio 3','Nome do sócio 4', 'Qualificação sócio 4', 'Tipo qualificação sócio 4', 'Nome do sócio 5', 'Qualificação sócio 5', 'Tipo qualificação sócio 5'])

# %%
df.to_excel(caminho + 'Output ' + arquivo + '.xlsx', index= False)
